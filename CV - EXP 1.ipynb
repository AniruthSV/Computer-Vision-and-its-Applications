# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
#reading and displaying an image
image = cv2.imread('/content/drive/MyDrive/CV Images/example.jpg')
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1919x1077>

# %%
#saving an image
cv2.imwrite('output.jpg', image)
print("Image saved as output.jpg")
# Out:
# Image saved as output.jpg

# %%
#conversion of image
#1.colour to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=1919x1077>

# %%
#2.conversion to HSV(hue,saturation,value)
image = cv2.imread('/content/drive/MyDrive/CV Images/example.jpg')
# Convert to HSV
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
# Display the image
cv2_imshow(hsv_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1919x1077>

# %%
#3.conversion to binary
_,binary_image = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)
cv2_imshow(binary_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=1919x1077>
